# %%
import requests 

BASE = "https://api.tfl.gov.uk"
BASE
# Out:
# 'https://api.tfl.gov.uk'

# %%
url = BASE + "/line/mode/tube/status"
url
# Out:
# 'https://api.tfl.gov.uk/line/mode/tube/status'

# %%
r = requests.get(url=url, timeout=10)
data = r.json()

# %%
print(data)
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities', 'id': 'bakerloo', 'name': 'Bakerloo', 'modeName': 'tube', 'disruptions': [], 'created': '2025-10-01T10:08:21.21Z', 'modified': '2025-10-01T10:08:21.21Z', 'lineStatuses': [{'$type': 'Tfl.Api.Presentation.Entities.LineStatus, Tfl.Api.Presentation.Entities', 'id': 0, 'statusSeverity': 10, 'statusSeverityDescription': 'Good Service', 'created': '0001-01-01T00:00:00', 'validityPeriods': []}], 'routeSections': [], 'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities', 'name': 'Regular', 'uri': '/Line/Route?ids=Bakerloo&serviceTypes=Regular'}], 'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}}, {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities', 'id': 'central', 'name': 'Central', 'modeName': 'tube', 'disruptions': [], 'created': '2025-10-01T10:08:21.21Z', 'modified': '2025-10-01T10:08
# ...

# %%
len(data)
# Out:
# 11

# %%
import pandas as pd
data = pd.DataFrame({

    
})

# %%
for line in data:
    break
line

# %%
pd.DataFrame(data)
# Out:
#                                                 $type                id  \
# 0   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...          bakerloo
# 1   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...           central
# 2   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...            circle
# 3   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...          district
# 4   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...  hammersmith-city
# 5   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...           jubilee
# 6   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...      metropolitan
# 7   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...          northern
# 8   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...        piccadilly
# 9   Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...          victoria
# 10  Tfl.Api.Presentation.Entities.Line, Tfl.Api.Pr...     waterloo-city
#
#                   name modeName disruptions                   created  \
# ...

# %%
data[0] ['lineStatuses']
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.LineStatus, Tfl.Api.Presentation.Entities',
#   'id': 0,
#   'statusSeverity': 10,
#   'statusSeverityDescription': 'Good Service',
#   'created': '0001-01-01T00:00:00',
#   'validityPeriods': []}]
